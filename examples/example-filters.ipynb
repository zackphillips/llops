# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import matplotlib.pyplot as plt
import llops as yp
import imageio
# Out:
# ('libforge.1.dylib', '/opt/arrayfire/lib/libforge.1.dylib')

# %% [markdown]
# ## Load Test Object

# %%
image_filename = '../resources/test_object.tiff'
x = yp.asarray(imageio.imread(image_filename), backend='numpy', dtype='float32')
plt.figure(figsize=(5,3))
plt.imshow(yp.real(x))
# Out:
# /Users/zfphil/develop/libwallerlab/submodules/ndoperators/submodules/llops/llops/base.py:1477: ComplexWarning: Casting complex values to real discards the imaginary part
#   return x.astype(getNativeDatatype(new_dtype, 'numpy'))
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ## Test Eroding Filter
# - Check Normalization
# - Check speed

# %%
yp.setDefaultBackend('numpy')

x = yp.zeros((2000,2000))
x[400:600,400:600] = 2

yp.filter.linearErodeInner(x, 50)

plt.figure()
plt.subplot(121)
plt.imshow(yp.real(x))
plt.subplot(122)
plt.imshow(yp.real(yp.filter.linearErodeInner(x, 50)))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
567
# Out:
# 567
