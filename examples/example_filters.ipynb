# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import matplotlib.pyplot as plt
import imageio

# Low-level operators (backend independent)
import llops as yp

import llops.filter as filters

# %%
image_filename = '../resources/test_object.tiff'
x = yp.asarray(imageio.imread(image_filename), backend='numpy', dtype='float32')
plt.figure(figsize=(5,3))
plt.imshow(yp.real(x))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ## Gallery of Filters (Real Object)

# %%
image = x

plt.figure(figsize=(10,10))
plt.subplot(351)
plt.imshow(yp.abs(image))
plt.title('Original')
plt.subplot(352)
plt.imshow(yp.abs(filters.sobel(image)))
plt.title('Sobel Filter')
plt.subplot(353)
plt.imshow(yp.abs(filters.canny(image)))
plt.title('Canny Filter')
plt.subplot(354)
plt.imshow(yp.abs(filters.roberts(image)))
plt.title('Roberts Filter')
plt.subplot(355)
plt.imshow(yp.abs(filters.prewitt(image)))
plt.title('Prewitt Filter')
plt.subplot(356)
plt.imshow(yp.abs(filters.scharr(image)))
plt.title('Scharr Filter')
plt.subplot(357)
plt.imshow(yp.abs(filters.laplace(image)))
plt.title('Laplace Filter')
plt.subplot(358)
plt.imshow(yp.abs(filters.gaussian(image)))
plt.title('Gaussian Filter')
plt.subplot(359)
plt.imshow(yp.abs(filters.median(image)))
plt.title('Median Filter')

# plt.subplot(3,5,12)
# plt.imshow(yp.abs(filters.bilateral(image)))
# plt.title('Bilateral Filter')

# %% [markdown]
# ## Gallary of Filters, Real Object, Arrayfire

# %%
import arrayfire as af
af.image.gaussian_kernel(100,1, 10)

# %%
image = yp.changeBackend(x, 'arrayfire')

plt.figure(figsize=(10,10))
plt.subplot(351)
plt.imshow(yp.abs(image))
plt.title('Original')
plt.subplot(352)
plt.imshow(yp.abs(filters.sobel(image)))
plt.title('Sobel Filter')
plt.subplot(353)
plt.imshow(yp.abs(filters.canny(image)))
plt.title('Canny Filter')
plt.subplot(354)
plt.imshow(yp.abs(filters.roberts(image)))
plt.title('Roberts Filter')
plt.subplot(355)
plt.imshow(yp.abs(filters.prewitt(image)))
plt.title('Prewitt Filter')
plt.subplot(356)
plt.imshow(yp.abs(filters.scharr(image)))
plt.title('Scharr Filter')
plt.subplot(357)
plt.imshow(yp.abs(filters.laplace(image)))
plt.title('Laplace Filter')
plt.subplot(358)
plt.imshow(yp.abs(filters.gaussian(image)))
plt.title('Gaussian Filter')
plt.subplot(359)
plt.imshow(yp.abs(filters.median(image)))
plt.title('Median Filter')

# plt.subplot(3,5,12)
# plt.imshow(yp.abs(filters.bilateral(image)))
# plt.title('Bilateral Filter')
# Out:
# <div id='0d81857d-6bad-4460-8eb9-859403064fe9'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ccabd510237c> in <module>
#      24 plt.title('Laplace Filter')
#      25 plt.subplot(358)
# ---> 26 plt.imshow(yp.abs(filters.gaussian(image)))
#      27 plt.title('Gaussian Filter')
#      28 plt.subplot(359)
#
# ~/develop/libwallerlab/submodules/ndoperators/submodules/llops/llops/filter.py in gaussian(x, sigma)
#     221
#     222     # Convolve and return
# --> 223     return iFt(Ft(x_padded) * Ft(kernel))
#     224
#     225
#
# ~/anaconda/lib/python3.7/site-packages/arrayfire/array.py in __mul__(self, other)
#     869         Return self * other.
#     870         """
# --> 871         return _binary_func(self, other, backend.get().af_mul)
#     872
#     873     def __imul__(self, other):
#
# ...

# %%
plt.figure()
plt.subplot(121)
plt.imshow(yp.abs(filters._gaussianKernel((100,100), 10, backend='arrayfire')))
plt.colorbar()

plt.subplot(122)
plt.imshow(yp.abs(filters._gaussianKernel((100,100), 10, backend='numpy')))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
x_np = yp.randn((100,100))
x_af = yp.changeBackend(x_np, 'arrayfire')

sigma = 1
y_np = yp.filter.canny(x_np, sigma=sigma)
y_af = yp.filter.canny(x_af, sigma=sigma)

plt.figure()
plt.subplot(131)
plt.imshow(yp.abs(yp.changeBackend(y_af, 'numpy')))
plt.subplot(132)
plt.imshow(yp.abs(y_np))
plt.subplot(133)
plt.imshow(yp.abs(y_np - yp.changeBackend(y_af, 'numpy')))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1200">
